# %%
# importación de pandas
import pandas as pd 

# importación de matplotlib. 
from matplotlib import pyplot as plt

# %%
# Ejemplo sencillo de uso de pyplot
x = [1, 2, 3]
y = [4, 5, 6]
z = [7, 8, 9]
# con la función plot() ploteamos la variable x en el eje x y la variable y en el eje y.
plt.plot(x, y)
# también podemos crear un segundo plot
plt.plot(x, z)
# Con esta instrucción añadimos un título
plt.title("First plot")
# Con esta instrucción añadimos un nombre al eje x
plt.xlabel("X")
# Con esta instrucción añadimos un nombre al eje y
plt.ylabel("Y and Z")
# Podemos añadir una leyenda con la función legend(). Esta función recibe como argumento una lista que dará una leyenda para cada plot
plt.legend(["X vs Y", "X vs Z"])

# %%
# importamos la data usando la función read_csv de pandas
sample_data = pd.read_csv("./data/sample_data.csv")
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
# Si queremos plotear una columna contra la otra debemos primero extraer las columns. Por ejemplo para A vs C
column_a = sample_data.column_a
column_b = sample_data.column_b
column_c = sample_data.column_c

plt.plot(column_a, column_c)
# Aquí el tercer argumento implica el tipo de plot. En este caso son puntitos
plt.plot(column_a, column_b, "o")
plt.title("Columns")
plt.xlabel("A")
plt.ylabel("B and C")
plt.legend(["A vs C", "A vs B"])

# Es posible extraer un valor en particular o fila haciendo uso de la función iloc. Estar recibe el índice que deseamos extraer. Po r ejemplo para tomar el primer registro de nuestro df
print(sample_data.iloc[0])
# Out:
# column_a     1
# column_b     1
# column_c    10
# Name: 0, dtype: int64

# %%
# Análisis con data real

# Importamos el csv de paises
countries = pd.read_csv("./data/countries.csv")
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
# Comparando el crecimiento poblacional entre US y China. Lo primero que queremos es es aislar la data de ambos países que son de interés

us = countries[countries["country"] == "United States"]

china = countries[countries["country"] == "China"]

# Luego podemos plotear. Nótese que dividimos por 1 millón para así ver la población en millones
plt.plot(us.year, us.population / 10**6)
plt.plot(china.year, china.population / 10**6)
plt.title("US Population vs China Population")
plt.xlabel("Years")
plt.ylabel("Population")
plt.legend(["US", "China"])

# %%
# Podemos comparar las cantidades relativas en lugar del valor absoluto. Para esto podemos hacer lo siguiente
plt.plot(us.year, us.population / us.population.iloc[0] *100)
plt.plot(china.year, china.population / china.population.iloc[0] * 100)
plt.title("US Population vs China Population")
plt.xlabel("Years")
plt.ylabel("Population")
plt.legend(["US", "China"])
